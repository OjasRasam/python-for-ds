# %% [markdown]
# ####  Classes and Objects
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %%
### A class is a blue print for creating objects. Attributes,methods
class Car:
    pass

audi = Car()
bmw = Car()

# %%
print(audi)
print(bmw)
print(type(audi))
# Out:
# <__main__.Car object at 0x0000022EE7B42BA0>
# <__main__.Car object at 0x0000022EE7B42B10>
# <class '__main__.Car'>

# %%
audi.windows = 4
print(audi.windows)
# Out:
# 4

# %%
tata = Car()
tata.doors = 4
print(tata.doors)
# Out:
# 4

# %%
dir(Car)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
### Instance Variable and Methods
class Dog:
    ## Constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age

## Create Object

dog1 = Dog("Buddy", 3)
print(dog1)
print(dog1.name, dog1.age)
# Out:
# <__main__.Dog object at 0x0000022EE7B2ADE0>
# Buddy 3

# %%
dog2 = Dog("Lucy", 4)
print(dog2.name, dog2.age)
# Out:
# Lucy 4

# %%
## Define a class with instance Methods
class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age
    
    def bark(self):
        print(f"{self.name} says woof...")

dog1 = Dog("Buddy", 3)
dog1.bark()

dog2 = Dog("Lucy", 4)
dog2.bark()
# Out:
# Buddy says woof...
# Lucy says woof...

# %%
## Modeling a Bank Account

# Defining a class for bank account

class BankAccount:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance
    
    def deposit(self, amount):
        self.balance += amount
        print(f"{amount} is deposited, New balance is {self.balance}")
    
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient Funds for transaction")
        else:
            self.balance -= amount
            print(f"Withdrew {amount}, New Balance {self.balance}")

    def get_balance(self):
        return self.balance
    
## Creating an account object
account1 = BankAccount("Ojas", 50000)
print(account1.owner , account1.balance)
# Out:
# Ojas 50000

# %%
## Call isntance methods
account1.deposit(50000)
print(account1.balance)
# Out:
# 50000 is deposited, New balance is 100000
# 100000

# %%
account1.withdraw(10000)
# Out:
# Withdrew 10000, New Balance 90000

# %%
account1.get_balance()
account1.deposit(10000)
account1.get_balance()
# Out:
# 10000 is deposited, New balance is 100000
# 100000

# %% [markdown]
# #### Conclusion
# Object-Oriented Programming (OOP) allows you to model real-world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations. Understanding these concepts is fundamental to writing effective and maintainable Python code.
