# %% [markdown]
# #### Decorators
# Decorators are a powerful and flexible feature in Python that allows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code. This lesson covers the basics of decorators, including how to create and use them.

# %%
### function copy
### closures
### decorators

# %%
## Function copy
def welcome():
    return "Welcome to the advance python coursee"

welcome()
# Out:
# 'Welcome to the advance python coursee'

# %%
wel = welcome
print(wel())
del welcome
print(wel())
# Out:
# Welcome to the advance python coursee
# Welcome to the advance python coursee

# %%
##closures functions

def main_welcome(msg):
    def sub_welcome_function():
        print("Welcome to the advance python course")
        print(msg)
        print("Please learn these concepts properly")
    return sub_welcome_function()

# %%
main_welcome("YOOO")
# Out:
# Welcome to the advance python course
# YOOO
# Please learn these concepts properly

# %%
def main_welcome(func):

    def sub_welcome_method():
        print("Welcome to the advance python course")
        func("Hello Worls")
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(print)
# Out:
# Welcome to the advance python course
# Hello Worls
# Please learn these concepts properly

# %%
def main_welcome(func,lst):
   
    def sub_welcome_method():
        print("Welcome to the advance python course")
        print(func(lst))
        print("Please learn these concepts properly")
    return sub_welcome_method()

# %%
main_welcome(len,[1,2,3,4,5])
# Out:
# Welcome to the advance python course
# 5
# Please learn these concepts properly

# %%
len([1,2,3,4,5,6])
# Out:
# 6

# %%
### Decorator
def main_welcome(func):

    def sub_welcome_mathod():
        print("Welcome to the advance python course") 
        func()
        print("Please learn these concepts properly")
    return sub_welcome_mathod()

# %%
def course_introduction():
    print("This is an advance python course")

main_welcome(course_introduction)
# Out:
# Welcome to the advance python course
# This is an advance python course
# Please learn these concepts properly

# %%
main_welcome(course_introduction)
# Out:
# Welcome to the advance python course
# This is an advance python course
# Please learn these concepts properly

# %%
@main_welcome
def course_introduction():
    print("HIE")
# Out:
# Welcome to the advance python course
# HIE
# Please learn these concepts properly

# %%
# Decorator

def my_decorator(func):
    def wrapper():
        print("Beforre Function call")
        func()
        print("After function call")
    return wrapper

# %%
@my_decorator
def say_hello():
    print("Hello")

# %%
say_hello()
# Out:
# Beforre Function call
# Hello
# After function call

# %%
# Decorators with arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hellooo")

# %%
say_hello()
# Out:
# Hellooo
# Hellooo
# Hellooo

# %% [markdown]
# #### Conclusion
# Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control, and more without changing the original code. Understanding and using decorators effectively can significantly enhance your Python programming skills.
