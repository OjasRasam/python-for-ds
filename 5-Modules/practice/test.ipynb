# %%
import sys
print(sys.path)
print("Hello World")
# Out:
# ['d:\\python\\venv\\python312.zip', 'd:\\python\\venv\\DLLs', 'd:\\python\\venv\\Lib', 'd:\\python\\venv', '', 'd:\\python\\venv\\Lib\\site-packages']
# Hello World

# %%
# !pip install requests

# %%
import requests
response = requests.get("https://google.com")
print(response.status_code)
# Out:
# 200
